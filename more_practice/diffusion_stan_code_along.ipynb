# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import stan
import arviz as az

import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ## Introduction
#
# In this notebook, we will estimate the parameters of the simple diffusion model from a simulated response times (RTs) data set using Stan's implementation of Hamiltonian Monte Carlo (HMC). But, wait! Since we are simulating the data (i.e., solving the forward problem), don't we already know the parameters with absolute certainty? Indeed, in this case we do, and this little exercise will introduce a crucial principle of all computational modeling: **Parametric models are nothing but assumptions about the unknown data-generating process**, so, in a way, the inverse problem (i.e., going from data to parameters) presupposes the forward problem.
#
# Thus, even when we are estimating the parameters from an actually observed data set, we are assuming that the parametric model is the accurate description of the system that generated the data. In other words, we hope that our model is *well-specified*. Simulation studies enable science *in silico*, that is, before collecting any data, we can already play oracles and test what we can learn from the data by successively solving the forward and the inverse problem.

# %% [markdown]
# ## Diffusion Model Simulator

# %%
def simulate_diffusion(v, a, beta, tau, dt=1e-3, scale=1.0, max_time=10., rng=None):
    """
    Simulates one realization of the diffusion process given
    a set of parameters and a step size `dt`.

    Parameters:
    -----------
    v        : float
        The drift rate (rate of information uptake)
    a        : float
        The boundary separation (decision threshold).
    beta     : float in [0, 1]
        Relative starting point (prior option preferences)
    tau      : float
        Non-decision time (additive constant)
    dt       : float, optional (default: 1e-3 = 0.001)
        The step size for the Euler algorithm.
    scale    : float, optional (default: 1.0)
        The scale (sqrt(var)) of the Wiener process. Not considered
        a parameter and typically fixed to either 1.0 or 0.1.
    max_time : float, optional (default: .10)
        The maximum number of seconds before forced termination.
    rng      : np.random.Generator or None, optional (default: None)
        A random number generator with locally set seed or None
        If None provided, a new generator will be spawned within the function.
        
    Returns:
    --------
    (x, c) - a tuple of response time (y - float) and a 
        binary decision (c - int) 
    """

    # Inits (process starts at relative starting point)
    y = beta * a
    num_steps = tau
    const = scale*np.sqrt(dt)
    if rng is None:
        rng = np.random.default_rng()

    # Loop through process and check boundary conditions
    while (y <= a and y >= 0) and num_steps <= max_time:

        # Perform diffusion equation
        z = rng.normal()
        y += v*dt + const*z

        # Increment step counter
        num_steps += dt

    if y >= a:
        c = 1.
    else:
        c = 0.
    return (round(num_steps, 4), c)

# %% [markdown]
# ## Helper Functions

# %%
def simulate_diffusion_n(num_sims, v, a, beta, tau, dt=1e-3, scale=1.0, max_time=10., rng=None):
    """Add a nice docstring."""

    # Inits
    data = np.zeros((num_sims, 2))
    if rng is None:
        rng = np.random.default_rng()
    
    # Create data set
    for n in range(num_sims):
        data[n, :] = simulate_diffusion(v, a, beta, tau, dt, scale, max_time, rng)
    return data


def visualize_data(data, figsize=(10, 5)):
    """Helper function to visualize a simple response time data set."""

    f, axarr = plt.subplots(1, 2, figsize=figsize)
    
    # Histogram of response times
    sns.histplot(
        data[:, 0][data[:, 1] == 1], ax=axarr[0], color='#AA0000', alpha=0.8, lw=2, label=f'Response 1')
    sns.histplot(
        data[:, 0][data[:, 1] == 0], ax=axarr[0], color='#0000AA', alpha=0.8, lw=2, label=f'Response 0')

    # Barplot of categorical responses
    response, frequency = np.unique(data[:, 1], return_counts=True)
    sns.barplot(x=response.astype(np.int32), y=frequency, ax=axarr[1], alpha=0.8, color='#00AA00')

    # Labels and embelishments
    axarr[0].set_xlabel('Response time (s)', fontsize=16)
    axarr[0].legend(fontsize=16)
    axarr[0].set_ylabel('Count', fontsize=16)
    axarr[1].set_xlabel('Response', fontsize=16)
    axarr[1].set_ylabel('Frequency', fontsize=16)
    for ax in axarr:
        sns.despine(ax=ax)
        ax.grid(alpha=0.1, color='black')

    f.suptitle('Data Summary', fontsize=18)

    f.tight_layout()

# %%
# Ensure reproducibility
RNG = np.random.default_rng(2024)

# Set ground-truth parameters
parameters = {
    'v': 1.6,
    'a': 0.8,
    'beta': 0.6,
    'tau': 0.4
}

# Set additional simulation settings
control = {
    'num_sims': 120,
    'rng': RNG,
    'dt': 1e-3
}

# Create data with above configuration
data = simulate_diffusion_n(**{**control, **parameters})

# %%
data
# Out:
# array([[0.486, 1.   ],
#        [0.616, 1.   ],
#        [0.459, 0.   ],
#        [0.452, 1.   ],
#        [0.491, 1.   ],
#        [0.516, 1.   ],
#        [0.653, 1.   ],
#        [0.493, 1.   ],
#        [0.691, 1.   ],
#        [0.546, 1.   ],
#        [0.467, 0.   ],
#        [0.548, 1.   ],
#        [0.787, 0.   ],
#        [0.85 , 1.   ],
#        [0.427, 1.   ],
#        [0.686, 1.   ],
#        [0.439, 1.   ],
#        [0.581, 0.   ],
#        [0.522, 1.   ],
#        [0.481, 1.   ],
#        [0.423, 1.   ],
#        [0.487, 1.   ],
#        [0.468, 1.   ],
#        [0.505, 1.   ],
#        [0.444, 1.   ],
#        [0.783, 1.   ],
#        [0.449, 1.   ],
#        [0.503, 1.   ],
#        [0.502, 1.   ],
#        [0.473, 1.   ],
#        [0.505, 1.   ],
#        [0.748, 1.   ],
#        [0.488, 1.   ],
#        [0.667, 1.   ],
#        [0.46 , 1.   ],
#        [0.426, 1.   ],
#        [0.416, 1.   ],
#        [0.46 , 1.   ],
#        [0.692, 1.   ],
#        [0.741, 1.   ],
#        [0.464, 1.   ],
#        [0.708, 1.   ],
#        [0.427, 0.   ],
#        [0.429, 1.   ],
#        [0.498, 1.   ],
#        [0.601, 1.   ],
#        [0.465, 1.   ],
#        [0.73 , 0.   ],
#        [0.457, 1.   ],
#        [0.46 , 1.   ],
#        [0.457, 1.   ],
#        [0.516, 1.   ],
#        [0.821, 1.   ],
#        [0.48 , 1.   ],
#        [0.64 , 1.   ],
#        [0.641, 1.   ],
#        [0.454, 1.   ],
#        [0.485, 1.   ],
#        [0.577, 1.   ],
#        [0.441, 1.   ],
#        [0.43 , 1.   ],
#        [0.496, 1.   ],
#        [0.437, 1.   ],
#        [0.571, 1.   ],
#        [0.455, 1.   ],
#        [0.412, 1.   ],
#        [0.53 , 1.   ],
#        [0.425, 1.   ],
#        [0.418, 1.   ],
#        [0.639, 0.   ],
#        [0.528, 0.   ],
#        [0.468, 1.   ],
#        [0.463, 1.   ],
#        [0.442, 1.   ],
#        [0.821, 1.   ],
#        [0.479, 0.   ],
#        [0.604, 1.   ],
#        [0.691, 1.   ],
#        [0.441, 1.   ],
#        [0.42 , 1.   ],
#        [0.541, 1.   ],
#        [0.506, 1.   ],
#        [0.465, 1.   ],
#        [0.455, 1.   ],
#        [0.538, 1.   ],
#        [0.417, 1.   ],
#        [0.436, 1.   ],
#        [0.555, 1.   ],
#        [0.69 , 1.   ],
#        [0.603, 1.   ],
#        [0.515, 1.   ],
#        [0.639, 1.   ],
#        [0.538, 0.   ],
#        [0.803, 1.   ],
#        [0.473, 1.   ],
#        [0.835, 1.   ],
#        [0.441, 0.   ],
#        [0.417, 1.   ],
#        [0.866, 1.   ],
#        [0.541, 1.   ],
#        [0.514, 1.   ],
#        [0.687, 1.   ],
#        [0.508, 1.   ],
#        [0.471, 1.   ],
#        [0.527, 1.   ],
#        [0.514, 1.   ],
#        [0.413, 1.   ],
#        [0.572, 1.   ],
#        [0.597, 0.   ],
#        [0.446, 1.   ],
#        [0.639, 0.   ],
#        [0.614, 1.   ],
#        [0.643, 1.   ],
#        [0.437, 1.   ],
#        [0.622, 1.   ],
#        [0.596, 1.   ],
#        [0.456, 1.   ],
#        [0.496, 1.   ],
#        [0.496, 1.   ],
#        [0.528, 1.   ]])

# %%
visualize_data(data)

# %% [markdown]
# ## Bayesian Parameter Estimation
#
# Now, we will write a Stan program to sample from the posterior of the diffusion model parameters given the observed data.

# %% [markdown]
# ### Prior Distributions

# %%
### Visualizing our priors the lazy way
f, axarr = plt.subplots(1, 4, figsize=(12, 3))
param_names = [r'Drift rate ($v$)', r'Boundary separation ($a$)', r'Bias ($\beta$)', r'Non-decision time ($\tau$)']
sns.histplot(np.random.gamma(3, 1, size=100000), color='maroon', ax=axarr[0])
sns.histplot(np.random.gamma(3, 1, size=100000), color='maroon', ax=axarr[1])
sns.histplot(np.random.beta(2, 2, size=100000), color='maroon', ax=axarr[2])
sns.histplot(np.random.gamma(2, 1, size=100000), color='maroon', ax=axarr[3])

for ax, p in zip(axarr, param_names):
    ax.set_title(p, fontsize=14)
    ax.set_xlabel('Parameter value', fontsize=12)
    ax.set_yticks([])
    ax.set_ylabel('')
    sns.despine(ax=ax)

f.tight_layout()

# %% [markdown]
# ### Stan Program

# %%
program_code = """

data {
    int<lower=1> N;
    vector[N] y;
    vector[N] c;
}

parameters {
    real<lower=0> v;
    real<lower=0> a;
    real<lower=0, upper=1> beta;
    real<lower=0> tau;
}

model {
    // Priors
    v ~ gamma(3, 1);
    a ~ gamma(3, 1);
    beta ~ beta(2, 2);
    tau ~ gamma(2, 1);

    // Likelihood (Wiener Model)
    for (n in 1:N) {
        if (c[n] == 1) {
            y[n] ~ wiener(a, tau, beta, v);
        }
        else {
            y[n] ~ wiener(a, tau, 1-beta, -v);
        }
    }
}
"""

# %% [markdown]
# ### Compilation and Sampling

# %%
# Prepare data in Stan friendly format
data_dict = {
    'y': data[:, 0], 
    'c': data[:, 1].astype(int),
    'N': data.shape[0]
}

# Compile model
diff_model = stan.build(program_code=program_code, data=data_dict)
# Out:
# Building...
# Building: found in cache, done.

# %%
# Posterior inference using MCMC
fit = diff_model.sample(num_chains=4, num_samples=1000, num_warmup=500)
# Out:
# Sampling:   0%
# Sampling:   0% (1/6000)
# Sampling:   0% (2/6000)
# Sampling:   0% (3/6000)
# Sampling:   0% (4/6000)
# Sampling:   2% (103/6000)
# Sampling:   3% (202/6000)
# Sampling:   5% (302/6000)
# Sampling:   7% (401/6000)
# Sampling:   8% (500/6000)
# Sampling:  10% (600/6000)
# Sampling:  12% (700/6000)
# Sampling:  13% (800/6000)
# Sampling:  15% (900/6000)
# Sampling:  18% (1100/6000)
# Sampling:  38% (2300/6000)
# Sampling:  60% (3600/6000)
# Sampling:  82% (4900/6000)
# Sampling: 100% (6000/6000)
# Sampling: 100% (6000/6000), done.
# Messages received during sampling:
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 4.40795 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 3.06583 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.921039 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 2.07506 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 3.59132 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 6.87516 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 3.19744 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.62173 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 2.83161 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 6.56147 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.51433 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.679867 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 5.08209 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 3.22702 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   Gradient evaluation took 0.001677 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 16.77 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 8.71247e+25 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 3.84451e+26 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 2.2119e+06 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 14.4157 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.575274 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.46259e+175 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 14.2698 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.440846 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.423, but must be greater than nondecision time = 0.425616 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.413614 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.414023 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.418483 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.4151 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412395 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.414563 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.436555 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412586 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.601958 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.414214 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.598968 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.42285 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.413255 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.418539 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.459, but must be greater than nondecision time = 0.476906 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412349 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.415146 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.433465 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Gradient evaluation took 0.001112 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 11.12 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.8775e+72 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 6.34806e+17 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 11431.9 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 4.50034 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.673492 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 4.19942e+55 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.879006 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.413903 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.416992 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412231 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.41228 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412556 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.517104 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.441853 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412116 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.422624 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.730595 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.501448 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.34016 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   Gradient evaluation took 0.001668 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 16.68 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 2.36676e+37 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 7.60149e+08 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 25.7236 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.553032 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412603 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.419245 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.438551 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.423, but must be greater than nondecision time = 0.425942 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.601087 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.459, but must be greater than nondecision time = 0.467265 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.420664 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.437104 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412412 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.27934 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   Gradient evaluation took 0.001182 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 11.82 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 2.0398e+48 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 3.54427e+11 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 144.458 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.803792 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 7.02406e+172 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 10.5382 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412267 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.423, but must be greater than nondecision time = 0.426873 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.413898 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.428383 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.436306 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.427589 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.417202 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.540956 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.

# %%
# Extract samples
df = fit.to_frame()

# %%
# Posterior summary statistics
az.summary(fit)
# Out:
#        mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# v     2.049  0.312   1.480    2.652      0.007    0.005    1819.0    1933.0
# a     0.902  0.051   0.807    0.996      0.001    0.001    2016.0    2154.0
# beta  0.552  0.040   0.474    0.622      0.001    0.001    1734.0    1860.0
# tau   0.391  0.006   0.380    0.401      0.000    0.000    1645.0    1578.0
#
#       r_hat
# v       1.0
# a       1.0
# beta    1.0
# tau     1.0

# %%
# Traceplots 
f = az.plot_trace(fit, compact=False, legend=True)
plt.tight_layout()

# %% [markdown]
# ## Real-Data Application

# %%
# Reading in example response times (RT) data
df = pd.read_csv('../data/rt_example_data.csv', delimiter=';')

# %%
df['RESPONSE']
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 235    0
# 236    0
# 237    0
# 238    0
# 239    0
# Name: RESPONSE, Length: 240, dtype: int64

# %%
real_data_dict = {
    "y": list(df["RT"]),
    "c": list(df["RESPONSE"]),
    "N": len(df["TRIAL"])
}

real_model = stan.build(program_code=program_code, data=real_data_dict)
# Out:
# Building...
# Building: found in cache, done.

# %%
real_fit = real_model.sample(num_chains=4, num_samples=1000, num_warmup=500)
# Out:
# Sampling:   0%
# Sampling:   0% (1/6000)
# Sampling:   0% (2/6000)
# Sampling:   0% (3/6000)
# Sampling:   2% (102/6000)
# Sampling:   3% (201/6000)
# Sampling:   5% (301/6000)
# Sampling:   7% (400/6000)
# Sampling:   8% (500/6000)
# Sampling:  10% (600/6000)
# Sampling:  12% (700/6000)
# Sampling:  13% (800/6000)
# Sampling:  15% (900/6000)
# Sampling:  17% (1000/6000)
# Sampling:  35% (2100/6000)
# Sampling:  57% (3400/6000)
# Sampling:  75% (4500/6000)
# Sampling:  80% (4800/6000)
# Sampling:  82% (4900/6000)
# Sampling:  83% (5001/6000)
# Sampling: 100% (6000/6000)
# Sampling: 100% (6000/6000), done.
# Messages received during sampling:
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 4.40795 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 3.06583 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 0.921039 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 2.07506 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 3.59132 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 6.87516 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 3.19744 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 1.62173 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 2.83161 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 6.56147 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 1.51433 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 0.679867 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 5.08209 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 3.22702 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   Gradient evaluation took 0.003343 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 33.43 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 6.30517e+39 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 2.78225e+40 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 6.45141e+09 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 105.939 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 0.947175 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3847, but must be greater than nondecision time = 0.3997 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 4.77419e+46 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 0.4921 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4013, but must be greater than nondecision time = 0.474334 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3847, but must be greater than nondecision time = 0.394193 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 0.601402 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4013, but must be greater than nondecision time = 0.433626 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# warn:Rejecting initial value:
# warn:  Log probability evaluates to log(0), i.e. negative infinity.
# warn:  Stan can't start sampling from this initial value.
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 0.495403 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   Gradient evaluation took 0.002252 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 22.52 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 19.5918 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 0.911421 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3847, but must be greater than nondecision time = 0.387639 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.370171 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.375158 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.36927 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3847, but must be greater than nondecision time = 0.398755 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 0.631633 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.383889 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.369723 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 1.34016 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   Gradient evaluation took 0.002467 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 24.67 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 2.56312e+18 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 6198.68 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 2.17892 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3847, but must be greater than nondecision time = 0.384883 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 2.84649 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.36851 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.367959 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.372312 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.376178 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.372004 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.372065 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.376204 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.38456 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 1.27934 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   Gradient evaluation took 0.00256 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 25.6 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 6.84386e+23 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 170289 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 4.70982 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 5.06749e+06 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.373966 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.368301 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.369836 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.368231 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 0.72331 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.3679, but must be greater than nondecision time = 0.369722 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 1.1863 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.4851, but must be greater than nondecision time = 0.522805 (in '/tmp/httpstan_21qmizsa/model_d2paldwp.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.

# %%
# Posterior summary statistics
az.summary(real_fit)
# Out:
#        mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# v     0.229  0.105   0.045    0.415      0.002    0.002    2064.0    1894.0
# a     0.989  0.030   0.933    1.045      0.001    0.000    3060.0    2508.0
# beta  0.510  0.020   0.473    0.548      0.000    0.000    3129.0    2785.0
# tau   0.350  0.004   0.343    0.356      0.000    0.000    3530.0    2602.0
#
#       r_hat
# v       1.0
# a       1.0
# beta    1.0
# tau     1.0

# %%
# Traceplots 
f = az.plot_trace(real_fit, compact=False, legend=True)
plt.tight_layout()
